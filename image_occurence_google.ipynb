# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
input_path = './data/csv/haneul_google_labels.csv'

# %%
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['font.family'] = 'appleGothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
google_df = pd.read_csv(input_path)

# %%
google_df
# Out:
#           label  frequency  confidence
# 0      Outdoors        366   93.272563
# 1        Nature        300   92.928045
# 2         Grass        279   97.477945
# 3        Person        214   97.239191
# 4    Vegetation        186   94.538609
# ..          ...        ...         ...
# 297  Rainforest          1   99.699821
# 298    Stroller          1   83.826241
# 299       Zebra          1   93.149986
# 300   Shipwreck          1   97.402023
# 301    Hibiscus          1   56.660133
#
# [302 rows x 3 columns]

# %%
google_top_labels1 = google_df.head(10)

# %%
google_top_labels1
# Out:
#         label  frequency  confidence
# 0    Outdoors        366   93.272563
# 1      Nature        300   92.928045
# 2       Grass        279   97.477945
# 3      Person        214   97.239191
# 4  Vegetation        186   94.538609
# 5     Scenery        173   89.437038
# 6        Reed        122   97.779098
# 7         Sky        111   93.788338
# 8       Field        106   91.244963
# 9        Path        103   97.184574

# %%
plt.figure(figsize=(12, 9))
plt.bar(google_top_labels1['label'], google_top_labels1['frequency'])
plt.xlabel('Label', loc='right')
plt.ylabel('Frequency', loc='top')
plt.title('Top 10 Labels (Google Images)', pad=10)
plt.xticks(rotation=45, ha="right")
plt.savefig('./result/barchart_google_images.png', bbox_inches='tight')
plt.show()

# %%
from wordcloud import WordCloud

# %%
google_top_labels2 = google_df.head(50)

# %%
wordcloud = WordCloud(width=1000, height=1000, background_color='white').generate_from_frequencies(google_top_labels2.set_index('label')['frequency'].to_dict())

# %%
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title("Google Images", pad=30)
plt.axis('off')
plt.savefig('./result/wordcloud_google_images.png')
plt.show()
